# %%
import numpy as np
median_list = []
similarities_list = []
models_list = ["all-mpnet-base-v2", "multi-qa-mpnet-base-dot-v1", "all-distilroberta-v1", "all-MiniLM-L12-v2", "multi-qa-distilbert-cos-v1", "all-MiniLM-L6-v2", "multi-qa-MiniLM-L6-cos-v1", "paraphrase-multilingual-mpnet-base-v2", "paraphrase-albert-small-v2", "paraphrase-multilingual-MiniLM-L12-v2", "paraphrase-MiniLM-L3-v2", "distiluse-base-multilingual-cased-v1", "distiluse-base-multilingual-cased-v2"]

# %%
from datasets import load_dataset

# Indicate the dataset id from the Hub
dataset_id = "sentence-transformers/natural-questions"
dataset = load_dataset(dataset_id, split="train")
"""
Dataset({
   features: ['query', 'answer'],
   num_rows: 100231
})
"""
print(dataset[0])
"""
{
   'query': 'when did richmond last play in a preliminary final',
   'answer': "Richmond Football Club Richmond began 2017 with 5 straight wins, a feat it had not achieved since 1995. A series of close losses hampered the Tigers throughout the middle of the season, including a 5-point loss to the Western Bulldogs, 2-point loss to Fremantle, and a 3-point loss to the Giants. Richmond ended the season strongly with convincing victories over Fremantle and St Kilda in the final two rounds, elevating the club to 3rd on the ladder. Richmond's first final of the season against the Cats at the MCG attracted a record qualifying final crowd of 95,028; the Tigers won by 51 points. Having advanced to the first preliminary finals for the first time since 2001, Richmond defeated Greater Western Sydney by 36 points in front of a crowd of 94,258 to progress to the Grand Final against Adelaide, their first Grand Final appearance since 1982. The attendance was 100,021, the largest crowd to a grand final since 1986. The Crows led at quarter time and led by as many as 13, but the Tigers took over the game as it progressed and scored seven straight goals at one point. They eventually would win by 48 points – 16.12 (108) to Adelaide's 8.12 (60) – to end their 37-year flag drought.[22] Dustin Martin also became the first player to win a Premiership medal, the Brownlow Medal and the Norm Smith Medal in the same season, while Damien Hardwick was named AFL Coaches Association Coach of the Year. Richmond's jump from 13th to premiers also marked the biggest jump from one AFL season to the next."
}
"""
# Out:
# {'query': 'when did richmond last play in a preliminary final', 'answer': "Richmond Football Club Richmond began 2017 with 5 straight wins, a feat it had not achieved since 1995. A series of close losses hampered the Tigers throughout the middle of the season, including a 5-point loss to the Western Bulldogs, 2-point loss to Fremantle, and a 3-point loss to the Giants. Richmond ended the season strongly with convincing victories over Fremantle and St Kilda in the final two rounds, elevating the club to 3rd on the ladder. Richmond's first final of the season against the Cats at the MCG attracted a record qualifying final crowd of 95,028; the Tigers won by 51 points. Having advanced to the first preliminary finals for the first time since 2001, Richmond defeated Greater Western Sydney by 36 points in front of a crowd of 94,258 to progress to the Grand Final against Adelaide, their first Grand Final appearance since 1982. The attendance was 100,021, the largest crowd to a grand final si
# ...

# %%
from sentence_transformers import SentenceTransformer


model = SentenceTransformer("all-mpnet-base-v2")
embeddings = model.encode([
    "The weather is lovely today.",
    "It's so sunny outside!",
    "He drove to the stadium.",
])
similarities = model.similarity(embeddings, embeddings)
print("Similarities", similarities)
print("Median of smilarities", np.median(similarities))


median_list.append(np.median(similarities))
similarities_list.append(similarities)
# Out:
# Similarities tensor([[1.0000, 0.6817, 0.0492],
#         [0.6817, 1.0000, 0.0421],
#         [0.0492, 0.0421, 1.0000]])
# Median of smilarities 0.68165445

# %%
from sentence_transformers import SentenceTransformer


model = SentenceTransformer("multi-qa-mpnet-base-dot-v1")
embeddings = model.encode([
    "The weather is lovely today.",
    "It's so sunny outside!",
    "He drove to the stadium.",
])
similarities = model.similarity(embeddings, embeddings)
print("Similarities", similarities)
print("Median of smilarities", np.median(similarities))


median_list.append(np.median(similarities))
similarities_list.append(similarities)
# Out:
# Similarities tensor([[32.8875, 25.5127, 10.7012],
#         [25.5127, 31.6403, 11.5639],
#         [10.7012, 11.5639, 39.7126]])
# Median of smilarities 25.512705

# %%
from sentence_transformers import SentenceTransformer


model = SentenceTransformer("all-distilroberta-v1")
embeddings = model.encode([
    "The weather is lovely today.",
    "It's so sunny outside!",
    "He drove to the stadium.",
])
similarities = model.similarity(embeddings, embeddings)
print("Similarities", similarities)
print("Median of smilarities", np.median(similarities))


median_list.append(np.median(similarities))
similarities_list.append(similarities)
# Out:
# Similarities tensor([[1.0000, 0.6699, 0.1119],
#         [0.6699, 1.0000, 0.0798],
#         [0.1119, 0.0798, 1.0000]])
# Median of smilarities 0.66991186

# %%
from sentence_transformers import SentenceTransformer


model = SentenceTransformer("all-MiniLM-L12-v2")
embeddings = model.encode([
    "The weather is lovely today.",
    "It's so sunny outside!",
    "He drove to the stadium.",
])
similarities = model.similarity(embeddings, embeddings)
print("Similarities", similarities)
print("Median of smilarities", np.median(similarities))


median_list.append(np.median(similarities))
similarities_list.append(similarities)
# Out:
# Similarities tensor([[1.0000, 0.7034, 0.1440],
#         [0.7034, 1.0000, 0.1262],
#         [0.1440, 0.1262, 1.0000]])
# Median of smilarities 0.7034127

# %%
from sentence_transformers import SentenceTransformer


model = SentenceTransformer("multi-qa-distilbert-cos-v1")
embeddings = model.encode([
    "The weather is lovely today.",
    "It's so sunny outside!",
    "He drove to the stadium.",
])
similarities = model.similarity(embeddings, embeddings)
print("Similarities", similarities)
print("Median of smilarities", np.median(similarities))


median_list.append(np.median(similarities))
similarities_list.append(similarities)
# Out:
# Similarities tensor([[1.0000, 0.6667, 0.1699],
#         [0.6667, 1.0000, 0.1556],
#         [0.1699, 0.1556, 1.0000]])
# Median of smilarities 0.66673595

# %%
from sentence_transformers import SentenceTransformer


model = SentenceTransformer("all-MiniLM-L6-v2")
embeddings = model.encode([
    "The weather is lovely today.",
    "It's so sunny outside!",
    "He drove to the stadium.",
])
similarities = model.similarity(embeddings, embeddings)
print("Similarities", similarities)
print("Median of smilarities", np.median(similarities))


median_list.append(np.median(similarities))
similarities_list.append(similarities)
# Out:
# Similarities tensor([[1.0000, 0.6660, 0.1046],
#         [0.6660, 1.0000, 0.1411],
#         [0.1046, 0.1411, 1.0000]])
# Median of smilarities 0.6659553

# %%
from sentence_transformers import SentenceTransformer


model = SentenceTransformer("multi-qa-MiniLM-L6-cos-v1")
embeddings = model.encode([
    "The weather is lovely today.",
    "It's so sunny outside!",
    "He drove to the stadium.",
])
similarities = model.similarity(embeddings, embeddings)
print("Similarities", similarities)
print("Median of smilarities", np.median(similarities))


median_list.append(np.median(similarities))
similarities_list.append(similarities)
# Out:
# Similarities tensor([[1.0000, 0.5637, 0.1662],
#         [0.5637, 1.0000, 0.1514],
#         [0.1662, 0.1514, 1.0000]])
# Median of smilarities 0.56369495

# %%
from sentence_transformers import SentenceTransformer


model = SentenceTransformer("paraphrase-multilingual-mpnet-base-v2")
embeddings = model.encode([
    "The weather is lovely today.",
    "It's so sunny outside!",
    "He drove to the stadium.",
])
similarities = model.similarity(embeddings, embeddings)
print("Similarities", similarities)
print("Median of smilarities", np.median(similarities))


median_list.append(np.median(similarities))
similarities_list.append(similarities)
# Out:
# Similarities tensor([[1.0000, 0.8119, 0.0800],
#         [0.8119, 1.0000, 0.1086],
#         [0.0800, 0.1086, 1.0000]])
# Median of smilarities 0.81193334

# %%
from sentence_transformers import SentenceTransformer


model = SentenceTransformer("paraphrase-albert-small-v2")
embeddings = model.encode([
    "The weather is lovely today.",
    "It's so sunny outside!",
    "He drove to the stadium.",
])
similarities = model.similarity(embeddings, embeddings)
print("Similarities", similarities)
print("Median of smilarities", np.median(similarities))


median_list.append(np.median(similarities))
similarities_list.append(similarities)
# Out:
# Similarities tensor([[1.0000, 0.5926, 0.1182],
#         [0.5926, 1.0000, 0.1695],
#         [0.1182, 0.1695, 1.0000]])
# Median of smilarities 0.59255826

# %%
from sentence_transformers import SentenceTransformer


model = SentenceTransformer("paraphrase-multilingual-MiniLM-L12-v2")
embeddings = model.encode([
    "The weather is lovely today.",
    "It's so sunny outside!",
    "He drove to the stadium.",
])
similarities = model.similarity(embeddings, embeddings)
print("Similarities", similarities)
print("Median of smilarities", np.median(similarities))


median_list.append(np.median(similarities))
similarities_list.append(similarities)
# Out:
# Similarities tensor([[1.0000, 0.8140, 0.1421],
#         [0.8140, 1.0000, 0.1580],
#         [0.1421, 0.1580, 1.0000]])
# Median of smilarities 0.81397283

# %%
from sentence_transformers import SentenceTransformer


model = SentenceTransformer("paraphrase-MiniLM-L3-v2")
embeddings = model.encode([
    "The weather is lovely today.",
    "It's so sunny outside!",
    "He drove to the stadium.",
])
similarities = model.similarity(embeddings, embeddings)
print("Similarities", similarities)
print("Median of smilarities", np.median(similarities))



median_list.append(np.median(similarities))
similarities_list.append(similarities)
# Out:
# Similarities tensor([[1.0000, 0.5960, 0.0138],
#         [0.5960, 1.0000, 0.0906],
#         [0.0138, 0.0906, 1.0000]])
# Median of smilarities 0.5960343

# %%
from sentence_transformers import SentenceTransformer


model = SentenceTransformer("distiluse-base-multilingual-cased-v1")
embeddings = model.encode([
    "The weather is lovely today.",
    "It's so sunny outside!",
    "He drove to the stadium.",
])
similarities = model.similarity(embeddings, embeddings)
print("Similarities", similarities)
print("Median of smilarities", np.median(similarities))


median_list.append(np.median(similarities))
similarities_list.append(similarities)
# Out:
# Similarities tensor([[1.0000, 0.4867, 0.0351],
#         [0.4867, 1.0000, 0.1395],
#         [0.0351, 0.1395, 1.0000]])
# Median of smilarities 0.48672506

# %%
from sentence_transformers import SentenceTransformer


model = SentenceTransformer("distiluse-base-multilingual-cased-v2")
embeddings = model.encode([
    "The weather is lovely today.",
    "It's so sunny outside!",
    "He drove to the stadium.",
])
similarities = model.similarity(embeddings, embeddings)
print("Similarities", similarities)
print("Median of smilarities", np.median(similarities))

median_list.append(np.median(similarities))
similarities_list.append(similarities)
# Out:
# Similarities tensor([[1.0000, 0.5527, 0.0466],
#         [0.5527, 1.0000, 0.1069],
#         [0.0466, 0.1069, 1.0000]])
# Median of smilarities 0.5527192

# %%
from matplotlib import pyplot as plt

plt.bar(models_list, median_list)
plt.xlabel("Models")
plt.ylabel("Median of similarities")
plt.xticks(rotation=90)
plt.title("Median of similarities for each model")
plt.show()

# %%
from matplotlib import pyplot as plt

plt.bar(models_list, similarities_list)
plt.xlabel("Models")
plt.ylabel("similarities")
plt.xticks(rotation=90)
plt.title("similarities for each model")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-1473629184.py in <cell line: 0>()
#       1 from matplotlib import pyplot as plt
#       2
# ----> 3 plt.bar(models_list, similarities_list)
#       4 plt.xlabel("Models")
#       5 plt.ylabel("similarities")
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/pyplot.py in bar(x, height, width, bottom, align, data, **kwargs)
#    2979     **kwargs,
#    2980 ) -> BarContainer:
# -> 2981     return gca().bar(
#    2982         x,
#    2983         height,
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1519     def inner(ax, *args, data=None, **kwargs):
#    1520         if data is None:
# -> 1521             return func(
#    1522                 ax,
#    1523                 *map(cbook.sanitize_sequence, args),
#
# ...
